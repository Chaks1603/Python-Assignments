# %% [markdown]
# ### 1. Use d1.txt to fit with the function $ y = mx + c $
#
# ## $m = \frac{N\sum x_i y_i - \sum x_i \sum y_i}{N\sum x_i^2 - (\sum x_i)^2} \qquad c = \frac{\sum y_i \sum x_i^2 - \sum x_i \sum x_i y_i}{N\sum x_i^2 - (\sum x_i)^2} $

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (20,12)
plt.rcParams['font.size'] = 40
plt.rcParams['legend.fontsize'] = 40

def fit(x,y):
    n = len(x)
    sx = sum(x)
    sx2 = sum(x**2)
    sy = sum(y)
    sxy = sum(x*y)
    b = (n*sx2-sx**2)
    m = (n*sxy-sx*sy)/b
    c = (sy*sx2-sx*sxy)/b
    return m,c

# %%
A1=np.loadtxt('d1.txt')
x1=A1[:,0]
y1=A1[:,1]
plt.plot(x1,y1,'c8')

m1,c1=fit(x1,y1)
Y1=m1*x1+c1
print('m :', m1 ,'\t\t c :',c1)
plt.plot(x1,Y1, 'r',linewidth=4)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.suptitle(r'$y=mx+c$',y=1)
plt.title('m : %0.4f  and c : %0.4f '%(m1,c1))
#plt.grid(True)
plt.legend(['data plot','best fit'],fontsize=40)
plt.show()
# Out:
# m : 5.162123314178963 		 c : -2.279160009472366

# %% [markdown]
# ### 2. Use d2.txt to fit with the function $ y = mx^2 + c$
#
# ## $m = \frac{N\sum x_i^2 y_i - \sum x_i^2 \sum y_i}{N\sum x_i^4 - (\sum x_i)^4} \qquad c = \frac{\sum y_i \sum x_i^4 - \sum x_i^2 \sum x_i^2 y_i}{N\sum x_i^4 - (\sum x_i)^4} $

# %%
A2=np.loadtxt('d2.txt')
X2=A2[:,0]
y2=A2[:,1]
plt.plot(X2,y2, 'c*')

x2=X2**2
m2,c2=fit(x2,y2)
Y2=m2*X2*X2+c2
print('m :', m2 ,'\t\t c :',c2)
plt.plot(X2,Y2, 'r',linewidth=4)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.suptitle(r'$y=mx^2+c$',y=1)
plt.title('m : %0.4f  and c : %0.4f '%(m2,c2))
#plt.grid(True)
plt.legend(['data plot','best fit'])
plt.show()
# Out:
# m : 2.0278366769475613 		 c : 6.361556161236751

# %% [markdown]
# ### 3. Use d3.txt to fit with the function $ y = \frac{a}{x^2} + b$
#
# ## $a = \frac{N\sum {\frac{1}{x_i^2}} y_i - \sum {\frac{1}{x_i^2}} \sum y_i}{N\sum {\frac{1}{x_i^4}} - (\sum {\frac{1}{x_i^2}})^2} \qquad b = \frac{\sum y_i \sum {\frac{1}{x_i^4}} - \sum {\frac{1}{x_i^2}} \sum {\frac{1}{x_i^2}} y_i}{N\sum {\frac{1}{x_i^4}} - (\sum {\frac{1}{x_i^2}})^2} $

# %%
A3=np.loadtxt('d3.txt')
X3=A3[:,0]
y3=A3[:,1]
plt.plot(X3,y3, 'cd')

x3=1/(X3**2)
m3,c3=fit(x3,y3)
Y3=(m3/(X3*X3))+c3
print('a :', m3 ,'\t\t b :',c3)
plt.plot(X3,Y3, 'r',linewidth=4)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.suptitle(r'$y=\frac{a}{x^2}+b$',y=1)
plt.title('a : %0.4f  and b : %0.4f '%(m3,c3))
#plt.grid(True)
plt.legend(['data plot','best fit'])
plt.show()
# Out:
# a : 3.0946860632401045 		 b : 9.996077635960587

# %% [markdown]
# ### 4. Use d4.txt to fit with the function $y = a \exp(-\frac{x}{x_0}) $
#
# ### $ \log y = -\frac{x}{x_0} + \log a => Y = xm + c $
# ### $\text{where} \qquad Y=\log y , \qquad m=-\frac{1}{x_0}, \qquad c=\log a =>  a=\exp(c)$
#
#
# ## $m = \frac{N\sum x_i y_i - \sum x_i \sum y_i}{N\sum x_i^2 - (\sum x_i)^2} \qquad c = \frac{\sum y_i \sum x_i^2 - \sum x_i \sum x_i y_i}{N\sum x_i^2 - (\sum x_i)^2} $

# %%
A=np.loadtxt('d4.txt')
X4=A[:,0]
Y4=A[:,1]
plt.plot(X4,Y4, 'b^')

B=np.array([i for i in A if i[0]>0 and i[1]>0])
x4=B[:,0]
y4=np.log(B[:,1])
m4,c4=fit(x4,y4)
a4=np.exp(c4)
x04=(-1/m4)
Y44=a4*np.exp(-X4/x04)
print('x\u2080 :', x04 ,'\t\t a :',a4)
plt.plot(X4,Y44,'g',linewidth=4)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.title(r'$x_0 :$ %0.4f  and $a :$ %0.4f '%(x04,a4))
plt.suptitle(r'$y=a.e^{(-\frac{x}{x_0})}$',y=1)
#plt.grid(True)
plt.legend(['data plot','best fit'])
plt.show()
# Out:
# x₀ : 3.0422247381722474 		 a : 2.8966152953748767

# %% [markdown]
# ### 5. Use d5.txt to fit with the function $y = ax^k$
#
# ### $\log y =  k\log x + \log a => Y = mX + c $
# ### $\text{where} \qquad Y = \log y ,\qquad m=k ,\qquad X = \log x ,\qquad c = \log a=>a=\exp(c)$
#
# ## $m = \frac{N\sum x_i y_i - \sum x_i \sum y_i}{N\sum x_i^2 - (\sum x_i)^2} \qquad c = \frac{\sum y_i \sum x_i^2 - \sum x_i \sum x_i y_i}{N\sum x_i^2 - (\sum x_i)^2} $

# %%
A5=np.loadtxt('d5.txt')
X5=A5[:,0]
Y5=A5[:,1]
plt.plot(X5,Y5, 'bh')

x5=np.log(A5[16:,0])
y5=np.log(A5[16:,1])
m5,c5=fit(x5,y5)
a5=np.exp(c5)
Y55=a5*(X5**m5)
print('k :', m5 ,'\t\t a :',a5)
plt.plot(X5,Y55, 'r',linewidth=4)
plt.xlabel(r'$x \rightarrow $')
plt.ylabel(r'$y \rightarrow $')
plt.title('k : %0.4f and a : %0.4f '%(m5,a5))
plt.suptitle(r'$y=ax^k $',y=1)
#plt.grid(True)
plt.legend(['data plot','best fit'])
plt.show()
# Out:
# k : 3.0408781654466184 		 a : 0.9141216120174546

# %% [markdown]
# Q5. Write a function my_lin_regression(f, x, y) where f is a list containing function objects to
# basis functions, and x and y are arrays containing noisy data. Assume that x and y are the same size.
# Let an estimation function for the data contained in x and y be defined as ˆ y(x) = β(1) · f1(x) +
# β(2) · f2(x)+· · ·+β(n) · fn(x), where n is the length of f. Your function should compute beta
# according to the least squares regression formula.

# %%
x6=np.linspace(0, 1, 101)
y6=1 + x6 + x6 * np.random.random(len(x6))
plt.plot(x6,y6,'bo')

m6,c6=fit(x6,y6)
Y6=m6*x6+c6
print('m :', m6 ,'\t\t c :',c6)
plt.plot(x6,Y6, 'r',linewidth=4)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.suptitle(r'$y=mx+c$',y=1)
plt.title('m : %0.4f and c : %0.4f '%(m6,c6))
#plt.grid(True)
plt.legend(['data plot','best fit'])
plt.show()
# Out:
# m : 1.5595430570047746 		 c : 0.9724661743662885

# %% [markdown]
# Q8.Write a program where x and y are arrays of the same size
#
# `x = np.linspace(0, 1, 1000)`
#
# `y = 2*np.exp(-0.5*x) + 0.25*np.random.random(len(x))`
#
# Let an estimation function for the data contained in x and y be defined as $y(x) = αe^{βx}$. Your function
# should compute α and β to solve the least squares regression formula. One may follow Q4

# %%
x8 = np.linspace(0, 1, 1000)
y8 = 2*np.exp(-0.5*x8) + 0.25*np.random.random(len(x8))
plt.plot(x8,y8,"b8", label = "data")

m8,c8=fit(x8,y8)
y8=np.log(2*np.exp(-0.5*x8) + 0.25*np.random.random(len(x8)))
m8,c8=fit(x8,y8)
a8=np.exp(c8)
x08=(-1/m8)
Y8=a8*np.exp(-x8/x08)
print('m :', m8 ,'\tc :',c8,'\ta:',a8,'\tx_0 :',x08)
plt.plot(x8, Y8, "r",linewidth=4, label="regression")
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.title("Least Square Regression on Exponential Model")
plt.legend()
plt.show()
# Out:
# m : -0.4607770670854032 	c : 0.7508676505773827 	a: 2.1188376299872784 	x_0 : 2.1702468968896276

# %%
x7 = np.linspace(0, 2*np.pi, 1000)
y7 = 3*np.sin(x7) - 2*np.cos(x7) + np.random.random(len(x7))
plt.plot(x7,y7,"b8", label = "data")

m7,c7=fit(x7,y7)
Y7= (3*np.sin(x7) - 2*np.cos(x7) - m7/2)
plt.plot(x7,Y7,'r',linewidth=4, label="regression")
print('m :', m7 ,'\t\t c :',c7)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.title("Least Square Regression")
plt.legend()
plt.show()
# Out:
# m : -0.906732006127922 		 c : 3.357089980200906

# %% [markdown]
# $x^2+x+1=y$

# %%
x6=np.linspace(0, 1, 101)
y6=1 + x6 + x6 * x6
plt.plot(x6,y6,'bo')
X=x6*x6+x6
m6,c6=fit(X,y6)
Y6=m6*x6*x6+m6*x6+c6
print('m :', m6 ,'\t\t c :',c6)
plt.plot(x6,Y6, 'r',linewidth=2)
plt.xlabel(r'$ x \rightarrow $')
plt.ylabel(r'$ y \rightarrow $')
plt.suptitle(r'$y=ax^2+bx+c$',y=1)
plt.title('m : %0.4f  and c : %0.4f '%(m6,c6))
#plt.grid(True)
plt.legend(['data plot','best fit'])
plt.show()
# Out:
# m : 0.9999999999999987 		 c : 1.0000000000000018

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 1000)
y = 3*np.sin(x) - 2*np.cos(x) + np.random.random(len(x))
f = [np.sin, np.cos]
plt.plot(x7,y7,"b8", label = "data")

y_est = np.polyfit(x, y,10)
plt.plot(x,np.polyval(y_est,x), "r",linewidth=4, label="regression")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Least Square Regression Example")
plt.legend()
plt.show()
