# %% [markdown]
#  Q1. Show that for $\large \displaystyle{\lim_{\sigma \to 0} \frac{1}{\sigma \sqrt{2\pi}} e^{-\frac{(x-\pi)^2}{2 {\sigma}^2}} = \delta(x-\pi)} $ :  $$\int \cos x\delta(x-\pi) dx = -1$$

# %%
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt
# %matplotlib inline
sigma=10
E,s=[],[]
def f(x):
    return np.cos(x)*(1/(sigma*(2*np.pi)**0.5))*np.exp(-(x-np.pi)**2/(2*(sigma)**2))
for i in range(10):
    a=si.quad(lambda x:f(x),np.pi-5*(sigma),np.pi+5*(sigma),limit=200)[0]
    sigma=sigma*0.5
    E.append(a)
    s.append(sigma)
    plt.plot(s,E,'b-')
    plt.xlabel(r'$ \sigma \rightarrow $',fontsize=16)
plt.show()

# %% [markdown]
#  Q2. Show that $\large\displaystyle{\lim_{\epsilon \to 0} \frac{1}{\pi}(\frac{\epsilon}{x^2 + \epsilon^2}) = \delta(x)} $ by applying it on two functions of $x$.

# %%
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt
# %matplotlib inline
E=5
A=[]
s=[]
def f(x):
    return np.cos(x)*(1/np.pi)*(E/(x**2+E**2))
for i in range(500):
    a=si.quad(lambda x:f(x),-150*E,150*E,limit=20000)[0]
    E=E*0.6
    A.append(a)
    s.append(E)
    plt.plot(s,A,'k-')
    plt.xlabel(r'$ \epsilon \rightarrow $',fontsize=26)
plt.show()

# %% [markdown]
#  Q3. Plot the following function in the domain $(-4\pi \le x \le 4\pi) :$ $ \\ $ $$\large f(x)=\tan^{-1}x \textrm{  for  } 0\le x <2\pi \textrm{  and  } f(x+2\pi)=f(x)$$ $\\ $
#      Reconstruct this function with its **Fourier Components**.

# %%
import numpy as np
import scipy.integrate as si
import matplotlib.pyplot as plt
from pylab import *
# %matplotlib inline

q1=[(-5*np.pi),(-4*np.pi),(-3*np.pi),(-2*np.pi),(-np.pi),
    0,np.pi,(2*np.pi),(3*np.pi),(4*np.pi),(5*np.pi)]
q2=[r'${-5\pi}$',r'${-4\pi}$',r'${-3\pi}$',r'${-2\pi}$',r'${-\pi}$',
    r'$0$',r'${\pi}$',r'${2\pi}$',r'${3\pi}$',r'${4\pi}$',r'${5\pi}$']

def f(X):
    return np.arctan(X%(2*np.pi))

x=np.linspace(-5*np.pi,5*np.pi,100000)
y=f(x)

fig = plt.figure(figsize=(20,5))
a = fig.add_subplot(111)
ax = gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
ax.plot(x,y,'co-')
ax.legend(['$tan^{-1} x$'],fontsize=15)
xlim(1.1*x.min(), 1.1*x.max())
xticks(q1,q2)
xlabel(r'$ x \rightarrow $', fontsize=20)
ax=plt.title(r'$tan^{-1}(x) $ plot',fontsize=20)
plt.show()

# %% [markdown]
#  For a function of fourier
#  $$ f(x) = \frac{1}{2}a_o + \sum_{n=1}^\infty a_n \cos nx + \sum_{n=1}^\infty b_n \sin nx $$
# where,
#  $ \displaystyle\qquad a_o = \frac{1}{2\pi} \int_{0}^{2\pi} f(x) \text{ d}x \\ $
#  $ \displaystyle\qquad a_n = \frac{1}{\pi} \int_{0}^{2\pi} f(x) \cos nx \text{ d}x \\ $
#  $ \displaystyle\qquad b_n = \frac{1}{\pi} \int_{0}^{2\pi} f(x) \sin nx \text{ d}x \text{ for n = 1,2,3,4.....}$

# %%
n=0
maxn=20  # intervals ; ** just like a fine knob beside a core knob
Ao=(1/(2*np.pi))*si.quad(lambda x:np.cos(n*x)*f(x),0,2*np.pi,limit=200)[0]
A,B=[0],[0]

for n in range(1,maxn):
    An=1/(np.pi)*si.quad(lambda x:np.cos(n*x)*f(x),0,2*np.pi,limit=200)[0]
    A.append(An)
    Bn=1/(np.pi)*si.quad(lambda x:np.sin(n*x)*f(x),0,2*np.pi,limit=200)[0]
    B.append(Bn)    
#print('Ao :',Ao,'\nAn :',A,'\nBn :',B)
F=Ao*np.ones(len(x))    
for n in range(maxn):
    F += A[n]*np.cos(n*x) + B[n]*np.sin(n*x)
    print(F)
fig = plt.figure(figsize=(20,6))
a = fig.add_subplot(111)
ax = gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))    
ax.plot(x,y,'co-',linewidth=4)
ax.plot(x,F,'k-.',linewidth=2)
xlim(1.1*x.min(), 1.1*x.max())
xticks(q1,q2)
xlabel(r'$ x \rightarrow $', fontsize=20)
ax=plt.legend(['$tan^{-1} x$','fourier'],fontsize=15)
ax=plt.title(r'Fourier components of $tan^{-1} x $  plot for $%0.f$ itterations'%(maxn),fontsize=20)
plt.show()
# Out:
# [1.1184673 1.1184673 1.1184673 ... 1.1184673 1.1184673 1.1184673]
# [1.3173006  1.31738473 1.31746884 ... 1.31713229 1.31721646 1.3173006 ]
# [1.23709385 1.23705778 1.23702171 ... 1.23716604 1.23712994 1.23709385]
# [1.27637544 1.27647291 1.27657035 ... 1.27618044 1.27627795 1.27637544]
# [1.25434629 1.2543053  1.25426433 ... 1.25442829 1.25438729 1.25434629]
# [1.26807698 1.26817625 1.26827549 ... 1.26787837 1.26797769 1.26807698]
# [1.2587873  1.25874566 1.25870402 ... 1.25887062 1.25882896 1.2587873 ]
# [1.2654771  1.26557661 1.2656761  ... 1.26527802 1.26537757 1.2654771 ]
# [1.26042695 1.26038522 1.2603435  ... 1.26051045 1.2604687  1.26042695]
# [1.2643787  1.26447824 1.26457776 ... 1.26417956 1.26427914 1.2643787 ]
# [1.26119916 1.26115742 1.26111569 ... 1.26128268 1.26124091 1.26119916]
# [1.26381448 1.26391403 1.26401355 ... 1.26361533 1.26371492 1.26381448]
# [1.26162441 1.26158267 1.26154094 ... 1.26170793 1.26166617 1.26162441]
# [1.26348573 1.26358527 1.2636848  ... 1.26328658 1.26338617 1.26348573]
# [1.26188397 1.26184223 1.2618005  ... 1.26196749 1.26192573 1.26188397]
# [1.26327713 1.26337667 1.26347619 ... 1.26307798 1.26317757 1.26327713]
# [1.26205419 1.26201245 1.26197072 ... 1.2621377  1.26209594 1.26205419]
# [1.26313639 1.26323594 1.26333546 ... 1.26293725 1.26303683 1.26313639]
# [1.2621719  1.26213016 1.26208843 ... 1.26225541 1.26221365 1.2621719 ]
# [1.26303693 1.26313648 1.26323599 ... 1.26283779 1.26293737 1.26303693]

# %%
n=0
maxn=20  # intervals ; ** just like a fine knob beside a core knob
Ao=(1/(2*np.pi))*si.quad(lambda x:np.cos(n*x)*f(x),0,2*np.pi,limit=200)[0]
A,B=[0],[0]

for n in range(1,maxn):
    An=1/(np.pi)*si.quad(lambda x:np.cos(n*x)*f(x),0,2*np.pi,limit=200)[0]
    A.append(An)
    Bn=1/(np.pi)*si.quad(lambda x:np.sin(n*x)*f(x),0,2*np.pi,limit=200)[0]
    B.append(Bn)    
    
for n in range(maxn):
    Ao=Ao+A[n]*np.cos(n*x)+B[n]*np.sin(n*x)

fig = plt.figure(figsize=(20,6))
a = fig.add_subplot(111)
ax = gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))    
ax.plot(x,y,'co-',linewidth=4)
ax.plot(x,Ao,'k-.',linewidth=2)
xlim(1.1*x.min(), 1.1*x.max())
xticks(q1,q2)
xlabel(r'$ x \rightarrow $', fontsize=20)
ax=plt.legend(['$tan^{-1} x$','fourier'],fontsize=15)
ax=plt.title(r'Fourier components of $tan^{-1} x $  plot for $%0.f$ itterations'%(maxn),fontsize=20)
plt.show()

# %%
n=0
maxn=100 # intervals ; ** just like a fine knob beside a core knob
Ao=(1/(2*np.pi))*si.quad(lambda x:np.cos(n*x)*f(x),0,2*np.pi,limit=200)[0]
A,B=[0],[0]

for n in range(1,maxn):
    An=1/(np.pi)*si.quad(lambda x:np.cos(n*x)*f(x),0,2*np.pi,limit=200)[0]
    A.append(An)
    Bn=1/(np.pi)*si.quad(lambda x:np.sin(n*x)*f(x),0,2*np.pi,limit=200)[0]
    B.append(Bn)    
    
for n in range(maxn):
    Ao=Ao+A[n]*np.cos(n*x)+B[n]*np.sin(n*x)
    
fig = plt.figure(figsize=(20,6))
a = fig.add_subplot(111)
ax = gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))    
ax.plot(x,y,'co-',linewidth=4)
ax.plot(x,Ao,'k-.',linewidth=1.1)
xlim(1.1*x.min(), 1.1*x.max())
xticks(q1,q2)
xlabel(r'$ x \rightarrow $', fontsize=20)
ax=plt.legend(['$tan^{-1} x$','fourier'],fontsize=15)
ax=plt.title(r'Fourier components of $tan^{-1} x $  plot for $%0.f$ itterations'%(maxn),fontsize=20)
plt.show()

# %% [markdown]
# 3. Plot the Fourier integral of the function:
# $$ f(x)=x\exp{(-\frac{x^2}{2\sigma^2})}$$
#
# Plot the imaginary part as a function of $k$ for three values of $\sigma$.
#
# Show that as increases the momentum uncertainty decreases. Also show that the real parts are zero in all cases.

# %%
import numpy as np
import scipy.integrate as si
from scipy.linalg import norm
import matplotlib.pyplot as plt

def f(x,k,s):
    return x*np.exp(-(x**2/(2*s**2)))*np.cos(k*x)
def g(x,k,s):
    return x*np.exp(-(x**2/(2*s**2)))*np.sin(k*x)

k=np.arange(-1,1,0.001)
sigma=[3*np.pi,4*np.pi,5*np.pi]

Real=[[si.quad(f,-np.inf,np.inf,limit=1000,args=(i,j))[0] for i in k] for j in sigma]
Imag=[[si.quad(g,-np.inf,np.inf,limit=1000,args=(i,j))[0] for i in k] for j in sigma] 

plt.subplots(figsize=(10,8))    
for i in range(len(sigma)):
    plt.plot(k,Imag[i])
    plt.xlabel("X")
    plt.ylabel("|Imaginary F(X)|")
    plt.legend(['$\sigma_1$','$\sigma_2$','$\sigma_3$'],fontsize=20)
    print(r'Real part norm for sigma_{%i} is :'%(i),norm(Real[i]))
plt.show()
# Out:
# Real part norm for sigma_{0} is : 0.0
# Real part norm for sigma_{1} is : 0.0
# Real part norm for sigma_{2} is : 0.0

# %% [markdown]
# 5. Calculate the Fourier integral of the following functions and the then plot the power spectrum, $ | \textrm{Fourier Transformation}|^2$ as a function of frequency :
#
# a) $f(x)=\left\{\begin{array}{rl}\sin x & \textrm{ for } 0\le x\le a,\\ 0 & \textrm{ elsewhere } \end{array} \right.$
#              (Repeat the problem for a= 1, 10, 100). Put comments about your observations on the effect of increasing $a$.
#
# b) $f(x)=\sin x +\sin 2x$
#
# c) $f(x)=\left\{\begin{array}{rl}\sin x & \textrm{ for } x<0,\\ \sin 2x & \textrm{ for } x \ge 0 \end{array} \right. \qquad$
#      (Comment on the differences between the power spectrum of case (b) and (c)

# %%
import matplotlib.pyplot as plt
from scipy.integrate import quad
import numpy as np

# %%
def f1_sin(x,t):
    return np.sin(x)*np.sin(x*t)

def f1_cos(x,t):
    return np.cos(x)*np.cos(x*t)
C=50
sig=np.pi*np.array([3,5,10])
T=np.linspace(-3,3,601)
yr1=[[C*quad(f1_cos,0,i,args=(t),limit=500)[0] for t in T] for i in sig]
yi1=[[C*quad(f1_sin,0,i,args=(t),limit=500)[0] for t in T] for i in sig]
y1=[[yr1[i][t]**2 + yi1[i][t]**2 for t in range(len(T))] for i in range(len(sig))]
plt.figure(figsize=(8,6))
for i in range(3):
    plt.plot(T,y1[i], label='%dπ'%(sig[i]/np.pi))
plt.legend()
plt.show()

# %%
def f2_sin(x,t):
    return (np.sin(x) + np.sin(2*x))*np.sin(x*t)

def f2_cos(x,t):
    return (np.sin(x) + np.sin(2*x))*np.cos(x*t)

N=100
sig=np.pi*np.array([3., 4., 5.])
T=np.linspace(-N,N,601)
yr2=[[quad(f2_cos,-i,i,args=(t),limit=500)[0] for t in T] for i in sig] 
yi2=[[quad(f2_sin,-i,i,args=(t),limit=500)[0] for t in T] for i in sig]
y2=[[yr2[i][t]**2 + yi2[i][t]**2 for t in range(len(T))] for i in range(len(sig))]
plt.figure(figsize=(12,8))
for i in range(3):
    plt.plot(T,y2[i],label='%dπ'%(sig[i]/np.pi))
plt.legend()
plt.show()

# %%
def f2_sin(x,t):
    return (np.sin(x) + np.sin(2*x))*np.sin(x*t)

def f2_cos(x,t):
    return (np.sin(x) + np.sin(2*x))*np.cos(x*t)

N=100
T=np.linspace(-3,3,601)
yr2=[quad(f2_cos,-N,N,args=(t),limit=500)[0] for t in T] 
yi2=[quad(f2_sin,-N,N,args=(t),limit=500)[0] for t in T] 
y2=[yr2[t]**2 + yi2[t]**2 for t in range(len(T))] 
plt.figure(figsize=(12,8))
plt.plot(T,y2)
plt.show()

# %%
def f3_sin(x,t):
    return (np.sin(x)*(x<0) + np.sin(2*x)*(x>0))*np.sin(x*t)

def f3_cos(x,t):
    return (np.sin(x)*(x<0) + np.sin(2*x)*(x>0))*np.cos(x*t)

N=100
T=np.linspace(-3,3,601)
yr3=[quad(f3_cos,-N,N,args=(t),limit=500)[0] for t in T] 
yi3=[quad(f3_sin,-N,N,args=(t),limit=500)[0] for t in T] 
y3=[yr3[t]**2 + yi3[t]**2 for t in range(len(T))] 
plt.figure(figsize=(12,8))
plt.plot(T,y3)
plt.show()

# %% [markdown]
# 6. Calculate the FFT of a signal $ F(t)=\sin 50t.$  $ \\ $
#    Change the sampling frequency and sampling time and see the effect on the power spectrum. $ \\ $
#    Do you see your observations in conformation with sampling theorem? You should be able to plot the abscissa of your power spectrum.

# %% [markdown]
# #### Set 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=948*Tp      # total time period
k=6           # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 32
# freq res. : 0.05274261603375527
# maxn. frequency : 1.6877637130801686

# %% [markdown]
# #### Set 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=700*Tp      # total time period
k=11          # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 1024
# freq res. : 0.07142857142857141
# maxn. frequency : 73.14285714285712

# %% [markdown]
# #### Set 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=700*Tp      # total time period
k=13           # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 4096
# freq res. : 0.07142857142857141
# maxn. frequency : 292.5714285714285

# %% [markdown]
# #### Set 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=700*Tp      # total time period
k=12           # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 2048
# freq res. : 0.07142857142857141
# maxn. frequency : 146.28571428571425

# %% [markdown]
# #### Set 5

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=800*Tp     # total time period
k=13           # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 4096
# freq res. : 0.06249999999999999
# maxn. frequency : 255.99999999999997

# %% [markdown]
# #### Set 6

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=800*Tp     # total time period
k=12           # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 2048
# freq res. : 0.06249999999999999
# maxn. frequency : 127.99999999999999

# %% [markdown]
# #### Set 7

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=50          # signal frequency
Tp=2*np.pi/w  # signal time period
T=700*Tp      # total time period
k=11          # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency for sampling
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X)
Yp=np.abs(fft.fft(Y))
Wp=np.arange(0,wmax,wo)  # taking the positive side
Wn=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(Wp,Yp[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(Wn,Yp[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 1024
# freq res. : 0.07142857142857141
# maxn. frequency : 73.14285714285712

# %% [markdown]
# ### Comments :
#               1. The number of data points should always be greater than or equal to the length of 𝜔/2𝜋
#               2.Choosing very short data point to compute can lead to poor results, particularly if we have short epochs
#                 and only if we are interested in analyzing lower frequencies.
#               3.Large data point can result in finer resolution of power spectrum, but can lead to noisy power spectrum.
#                 One needs to strike a balance here, depending on the frequencies of interest.

# %% [markdown]
# 7. Calculate the FFT of a signal $F(t)=\sin t + \sin \pi t $. Plot the signal and its power spectrum. Write
# your comments.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=1           # signal frequency
Tp=2*np.pi/w  # signal time period
T=1000*Tp     # total time period
k=10          # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency 
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X) + np.sin(np.pi*X)
YP=np.abs(fft.fft(Y))
WP=np.arange(0,wmax,wo)  # taking the positive side
WN=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(WP,YP[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(WN,YP[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 512
# freq res. : 0.001
# maxn. frequency : 0.512

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=1           # signal frequency
Tp=2*np.pi/w  # signal time period
T=1000*Tp     # total time period
k=8           # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency 
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X) + np.sin(np.pi*X)
YP=np.abs(fft.fft(Y))
WP=np.arange(0,wmax,wo)  # taking the positive side
WN=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(WP,YP[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(WN,YP[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 128
# freq res. : 0.001
# maxn. frequency : 0.128

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=1           # signal frequency
Tp=2*np.pi/w  # signal time period
T=1000*Tp     # total time period
k=12          # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency 
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X) + np.sin(np.pi*X)
YP=np.abs(fft.fft(Y))
WP=np.arange(0,wmax,wo)  # taking the positive side
WN=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(WP,YP[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(WN,YP[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 2048
# freq res. : 0.001
# maxn. frequency : 2.048

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=1           # signal frequency
Tp=2*np.pi/w  # signal time period
T=800*Tp      # total time period
k=10          # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency 
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X) + np.sin(np.pi*X)
YP=np.abs(fft.fft(Y))
WP=np.arange(0,wmax,wo)  # taking the positive side
WN=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(WP,YP[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(WN,YP[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 512
# freq res. : 0.00125
# maxn. frequency : 0.64

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fft
w=1           # signal frequency
Tp=2*np.pi/w  # signal time period
T=800*Tp     # total time period
k=9          # intevals
N=2**k        # total no. of data points
Nh=int(N/2)   # sampling the spectrum into equal two parts
X,h=np.linspace(0,T,N, retstep=True)
wo=2*np.pi/T  # frequency resolution
wmax=wo*Nh    # max frequency 
print ('sampling :',Nh,'\nfreq res. :', wo,'\nmaxn. frequency :', wmax)
Y=np.sin(w*X) + np.sin(np.pi*X)
YP=np.abs(fft.fft(Y))
WP=np.arange(0,wmax,wo)  # taking the positive side
WN=np.arange(-wmax,0,wo) # taking the negative side
fig,(ax,ax1,ax2)=plt.subplots(1,3,figsize=(16,6))
plt.suptitle('Power Spectrum',y=0.99,fontsize=30)
ax.plot(X[:100],Y[:100],linewidth=3)
ax.set_title('Sample data',fontsize=20)
ax1.plot(WP,YP[:Nh])
ax1.set_title('+ve frequencies',fontsize=20)
ax2.plot(WN,YP[Nh:])
ax2.set_title('-ve frequencies',fontsize=20)
plt.show()
# Out:
# sampling : 256
# freq res. : 0.00125
# maxn. frequency : 0.32

# %% [markdown]
# ### Comment:
#                 Highly overlapping  data points does not guarantee smoother power spectrum estimates
#                 due to high correlation between the data points
