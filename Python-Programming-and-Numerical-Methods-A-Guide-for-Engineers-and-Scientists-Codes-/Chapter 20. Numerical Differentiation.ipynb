# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The **forward difference** estimates the slope of the function at $x_j$ using the line that connects
# $(x_j,f(x_j)) \text{ and } (x_{j+1},f(x_{j+1}))$:
# $$f'(x_j) = \frac{f(x_{j+1})−f(x_j)}{x_{j+1} −x_j}$$
# The **backward difference** estimates the slope of the function at $x_j$ using the line that connects
# $(x_{j−1},f(x_{j−1})) \text{ and } (x_j,f(x_j))$:
# $$f'(x_j) = \frac{f(x_j)−f(x_{j-1})}{x_j −x_{j-1}}$$
# The **central difference** estimates the slope of the function at $x_j$ using the line that connects
# $(x_{j−1},f(x_{j−1})) \text{ and } (x_{j+1},f(x_{j+1}))$:
# $$f'(x_j) = \frac{f(x_{j+1})−f(x_{j-1})}{x_{j+1} −x_{j-1}}$$

# %% [markdown]
# 1. Write a function `my_der_calc(f, a, b, N, option)` with the output as [df,X], where f is a function object, a and b are scalars such that a < b, N is an integer bigger than 10, and option is the string "forward", "backward", or "central". Let x be an array starting at a, ending at b, containing N evenly spaced elements, and let y be the array f(x). The output argument, df, should be the numerical derivatives computed for x and y according to the method defined by the input argument, option. The output argument X should be an array the same size as df, containing the points in x for which df is valid. Specifically, the forward difference method “loses” the last point, the backward difference method loses the first point, and the central difference method loses the first and last points.

# %%
def my_der_calc(f, a, b, N, option):
    assert isinstance(N, int) and N > 10, "N must be an integer greater than 10."
    assert option in ["forward", "backward", "central"], "Option must be 'forward', 'backward', or 'central'."
   
    x=np.linspace(a,b,N)
    n=N
    y = f(x)
    if option == "forward":
        X=x[0:n-1]
        df=(f(x[1:n])-f(x[0:n-1]))/(x[1:n]-x[0:n-1])
    elif option == "backward":
        X=x[1:n]
        df=(f(x[1:n])-f(x[0:n-1]))/(x[1:n]-x[0:n-1])
    else :
        X=x[1:n-1]
        df=(f(x[2:n])-f(x[0:n-2]))/(x[2:n]-x[0:n-2])

    return [df, X]

# %%
f = lambda x: np.sin(x)
x = np.linspace(0, 2*np.pi, 100)

dya, Xa = my_der_calc(f, 0, 2*np.pi, 11, 'forward')
dyb, Xb = my_der_calc(f, 0, 2*np.pi, 11, 'backward')
dyc, Xc = my_der_calc(f, 0, 2*np.pi, 11, 'central')
plt.figure(figsize = (12, 8))
plt.plot(x, np.cos(x), label = 'analytic')
plt.plot(Xa, dya, label = 'forward')
plt.plot(Xb, dyb, label = 'backward')
plt.plot(Xc, dyc, label = 'central')
plt.legend()
plt.title('Analytic and Numerical Derivatives of Sine')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Q2.Write a function `my_der_calc(f, a, b, N, option)`, with the output as $[df, X]$, where f is a function object.
# The function **my_num_diff** should compute the derivative of f numerically for n evenly spaced points
# starting at a and ending at $b$, according to the method defined by **option**.
#
# The input argument **option** is one of the following strings: **"forward", "backward", and "central".**
# Note that for the **forward** and **backward method**, the output argument, $dy$, should be a 1D array of length $(n−1)$,
# and for the central difference method **dy** it should be a 1D array of length $(n−2)$.
# The function should also output a vector $X$ that is the same size as dy and denotes the x-values for which **dy** is valid.

# %%
def my_num_diff(f,a,b,N,option):
    n=N
    x=np.linspace(a,b,n)
    if option == "forward":
        X=x[0:n-1]
        df=(f(x[1:n])-f(x[0:n-1]))/(x[1:n]-x[0:n-1])
    elif option == "backward":
        X=x[1:n]
        df=(f(x[1:n])-f(x[0:n-1]))/(x[1:n]-x[0:n-1])
    else :
        X=x[1:n-1]
        df=(f(x[2:n])-f(x[0:n-2]))/(x[2:n]-x[0:n-2])
    return df,X

# %%
f = lambda x: np.sin(x)
x = np.linspace(0, 2*np.pi, 100)

[dya, Xa] = my_num_diff(f, 0, 2*np.pi, 10, 'forward')
[dyb, Xb] = my_num_diff(f, 0, 2*np.pi, 10, 'backward')
[dyc, Xc] = my_num_diff(f, 0, 2*np.pi, 10, 'central')
plt.figure(figsize = (12, 8))
plt.plot(x, np.cos(x), label = 'analytic')
plt.plot(Xa, dya, label = 'forward')
plt.plot(Xb, dyb, label = 'backward')
plt.plot(Xc, dyc, label = 'central')
plt.legend()
plt.title('Analytic and Numerical Derivatives of Sine')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
f = lambda x: np.sin(np.exp(x))
x = np.linspace(0, np.pi, 1000)

[dy10, X10] = my_num_diff(f, 0, np.pi, 10, "central")
[dy20, X20] = my_num_diff(f, 0, np.pi, 20, "central")
[dy100, X100] = my_num_diff(f, 0, np.pi, 100, "central")
plt.figure(figsize = (12, 8))
plt.plot(x, np.cos(np.exp(x)), label = "analytic")
plt.plot(X10, dy10, label = "10 points")
plt.plot(X20, dy20, label = "20 points")
plt.plot(X100, dy100, label = "100 points")
plt.legend()
plt.title("Analytic and Numerical Derivatives of Sine")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# 3. Write a function `my_num_diff_w_smoothing(x,y,n)` with output [dy,X], where x and y are a 1D NumPy array of the same length, and n is a strictly positive scalar.
# The function should first create a vector of “smoothed” y data points where y_smooth[i] = np.mean(y[i-n:i+n]).
# The function should then compute dy, the derivative of the smoothed y-vector, using the central difference method.
# The function should also output a 1D array X that is the same size as dy and denotes the x-values for which dy is valid.
# Assume that the data contained in x is in ascending order with no duplicate entries; it is possible that the elements of x will not be evenly spaced.
# Note that the output dy will have 2n+2 fewer points than y.
# Assume that the length of y is much bigger than 2n+2.

# %%
def my_num_diff_w_smoothing(x,y,n):
    x_smooth=x[np.arange(n, len(x)-n,n)]
    def smoothD(x,y,n):
        discrete = np.arange(n+1,len(y)-n,n)
        s=[]
        for k in range(0,len(discrete)):
            i=discrete[k]
            s.append(np.average(y[np.arange(i-n-1,i+n)]))
        return np.array(s)
    
    def central_difference(y,h):
        dy=[]
        for i in range(1,len(y)-1):
            dy.append((y[i+1]-y[i-1])/(2*h))
        return np.array(dy)
    y_smooth=smoothD(x,y,n)
    X=x_smooth[np.arange(1,len(x_smooth)-1)]
    h=(X[len(X)-1]-X[0])/(len(X)-1)
    dy=central_difference(y_smooth,h)
    return (dy,X)

# %%
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x) + np.random.randn(len(x))/100
[dy, X] = my_num_diff_w_smoothing(x, y, 4)
plt.figure(figsize = (12, 12))
plt.subplot(211)
plt.plot(x, y)
plt.title("Noisy Sine function")
plt.xlabel("x")
plt.ylabel("y")
plt.subplot(212)
plt.plot(x, np.cos(x), "b", label = "cosine")
plt.plot(x[:-1], (y[1:] - y[:-1])/(x[1]-x[0]), "g", \
label = "unsmoothed forward diff")
plt.plot(X, dy, "r", label = "smoothed")
plt.title("Analytic Derivative and Smoothed Derivative")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Use Taylor series to show the following approximations and their accuracy:
#
# $\qquad\displaystyle f''(x_j ) = \frac{−f (x_{j+3})+ 4f(x_{j+2})−5f(x_{j+1})+2f(x_j )}{h^2}+ O(h^2),$
# $\qquad\displaystyle f'''(x_j ) = \frac{f (x_{j+3}) −3f (x_{j+2})+3f (x_{j+1})− f (x_j )}{h^3}+O(h).$

# %%
def approximations(x, h):
    f_double_prime = (-f(x + 3*h) + 4*f(x + 2*h) - 5*f(x + h) + 2*f(x)) / (h**2)
    f_triple_prime = (f(x + 3*h) - 3*f(x + 2*h) + 3*f(x + h) - f(x)) / (h**3)
    return f_double_prime, f_triple_prime

x_j = 1 # Choose the desired point
h = 0.1 # Choose the step size
f_double_prime_approx, f_triple_prime_approx = approximations(x_j, h)
print("Approximation for f''(x_j):", f_double_prime_approx)
print("Approximation for f'''(x_j):", f_triple_prime_approx)
# Out:
# Approximation for f''(x_j): -7.016867812775083
# Approximation for f'''(x_j): 29.383552269742257

# %%
from sympy import *
from IPython.display import display, Math


# Define the symbolic variables
x, h = symbols('x h')

# Define the function f(x)
f = Function('f')(x)

# Compute the Taylor series expansions
taylor_expansion_2nd_order = f.series(x, x_j, 4).removeO().subs(x, x_j + h)
taylor_expansion_3rd_order = f.series(x, x_j, 4).removeO().subs(x, x_j + h)

# Compute the approximations
approximation_2nd_order = (-f.subs(x, x_j + 3*h) + 4*f.subs(x, x_j + 2*h) - 5*f.subs(x, x_j + h) + 2*f.subs(x, x_j)) / h**2
approximation_3rd_order = (f.subs(x, x_j + 3*h) - 3*f.subs(x, x_j + 2*h) + 3*f.subs(x, x_j + h) - f.subs(x, x_j)) / h**3

# Display the Taylor series expansions and approximations
print("Taylor Series Expansions:")
display(Math("f''(x_j) ="+latex( taylor_expansion_2nd_order)))
display(Math("f'''(x_j) ="+latex( taylor_expansion_3rd_order)))
print()
print("Approximations:")
display(Math("f''(x_j) ="+latex( approximation_2nd_order)))
display(Math("f'''(x_j) ="+latex( approximation_3rd_order)))
# Out:
# Taylor Series Expansions:
# $\displaystyle f''(x_j) =\frac{h^{3} \left. \frac{d^{3}}{d \xi_{1}^{3}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }}}{6} + \frac{h^{2} \left. \frac{d^{2}}{d \xi_{1}^{2}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }}}{2} + h \left. \frac{d}{d \xi_{1}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }} + f{\left(1 \right)}$
# $\displaystyle f'''(x_j) =\frac{h^{3} \left. \frac{d^{3}}{d \xi_{1}^{3}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }}}{6} + \frac{h^{2} \left. \frac{d^{2}}{d \xi_{1}^{2}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }}}{2} + h \left. \frac{d}{d \xi_{1}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }} + f{\left(1 \right)}$
# Approximations:
# $\displaystyle f''(x_j) =\frac{2 f{\left(1 \right)} - 5 f{\left(h + 1 \right)} + 4 f{\left(2 h + 1 \right)} - f{\left(3 h + 1 \right)}}{h^{2}}$
# $\displaystyle f'''(x_j) =\frac{- f{\left(1 \right)} + 3 f{\left(h + 1 \right)} - 3 f{\left(2 h + 1 \right)} + f{\left(3 h + 1 \right)}}{h^{3}}$

# %%
# Display the Taylor series expansions and approximations
print("Taylor Series Expansions:")
display(Math("f''(x_j) ="+latex( taylor_expansion_2nd_order.subs([(x_j,1),(h,0.1)]))))
display(Math("f'''(x_j) ="+latex( taylor_expansion_3rd_order.subs([(x_j,1),(h,0.1)]))))
print()
print("Approximations:")
display(Math("f''(x_j) ="+latex( approximation_2nd_order.subs([(x_j,1),(h,0.1)]))))
display(Math("f'''(x_j) ="+latex( approximation_3rd_order.subs([(x_j,1),(h,0.1)]))))
# Out:
# Taylor Series Expansions:
# $\displaystyle f''(x_j) =f{\left(1 \right)} + 0.1 \left. \frac{d}{d \xi_{1}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }} + 0.005 \left. \frac{d^{2}}{d \xi_{1}^{2}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }} + 0.000166666666666667 \left. \frac{d^{3}}{d \xi_{1}^{3}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }}$
# $\displaystyle f'''(x_j) =f{\left(1 \right)} + 0.1 \left. \frac{d}{d \xi_{1}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }} + 0.005 \left. \frac{d^{2}}{d \xi_{1}^{2}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }} + 0.000166666666666667 \left. \frac{d^{3}}{d \xi_{1}^{3}} f{\left(\xi_{1} \right)} \right|_{\substack{ \xi_{1}=1 }}$
# Approximations:
# $\displaystyle f''(x_j) =200.0 f{\left(1 \right)} - 500.0 f{\left(1.1 \right)} + 400.0 f{\left(1.2 \right)} - 100.0 f{\left(1.3 \right)}$
# $\displaystyle f'''(x_j) =- 1000.0 f{\left(1 \right)} + 3000.0 f{\left(1.1 \right)} - 3000.0 f{\left(1.2 \right)} + 1000.0 f{\left(1.3 \right)}$
